# %%
import pandas as pd
import os

# %%
path = os.path.abspath("/Users/josh/Developer/Python/Pokemon/")
datapath = os.path.join(path, "data.csv")

# %%
dataframe = pd.read_csv(datapath)

# %%
dataframe
# Out:
#     Attacker  Defender  Relationship
# 0     Normal    Normal           NaN
# 1       Fire      Fire           NaN
# 2      Water     Water           NaN
# 3      Grass     Grass           NaN
# 4   Electric  Electric           NaN
# 5        Ice       Ice           NaN
# 6   Fighting  Fighting           NaN
# 7     Poison    Poison           NaN
# 8     Ground    Ground           NaN
# 9     Flying    Flying           NaN
# 10   Psychic   Psychic           NaN
# 11       Bug       Bug           NaN
# 12      Rock      Rock           NaN
# 13     Ghost     Ghost           NaN
# 14    Dragon    Dragon           NaN
# 15      Dark      Dark           NaN
# 16     Steel     Steel           NaN
# 17     Fairy     Fairy           NaN
